# %%
# 2-1
name = input("이름을 입력하세요: ")
age = input("나이를 입력하세요: ")

print(f"안녕하세요! 제 이름은 {name}이고, 나이는 {age}살입니다.")
# Out:
# 안녕하세요! 제 이름은 심소담이고, 나이는 22살입니다.

# %%
# 2-2
text = input("문자열을 입력하세요: ")

print(f"대문자: {text.upper()}")
print(f"소문자: {text.lower()}")
print(f"문자열 길이: {len(text)}")
# Out:
# 대문자: HELLO WORLD
# 소문자: hello world
# 문자열 길이: 11

# %%
# 2-3
email = input("이메일 주소를 입력하세요: ")

# @ 기준으로 분리 (split 함수)
user, domain = email.split('@')

print(f"사용자명: {user}")
print(f"도메인: {domain}")
# Out:
# 사용자명: user
# 도메인: example.com

# %%
# 2-4
sentence = input("문장을 입력하세요: ")

# 공백 기준으로 단어 분리하여 리스트 생성
words = sentence.split()
# 뽑아낸 단어들을 공백 한 칸(" ")을 사이에 두고 다시 합침
clear = " ".join(words)

print(f"공백 제거: {clear}")
print(f"단어 개수: {len(words)}개")
# Out:
# 공백 제거: Python is great
# 단어 개수: 3개

# %%
# 2-5
text = input("문자열을 입력하세요: ")
find = input("찾을 문자를 입력하세요: ")

count = text.count(find)
print(f"문자 '{find}이 {count}번 나타납니다.")
# Out:
# 문자 'm이 2번 나타납니다.
